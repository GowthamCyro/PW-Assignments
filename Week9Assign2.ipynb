# %% [markdown]
# Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of
# Matplotlib.

# %% [markdown]
# Matplotlib is a popular Python library used for creating static, interactive, and animated visualizations. It is widely used in the data science and scientific communities for data analysis, exploration, and communication of results.
#
# The Pyplot module in Matplotlib provides a simple and easy-to-use interface for creating various types of plots. It is typically imported as plt. Some of the common plots that can be plotted using the Pyplot module of Matplotlib are:
#
# Line Plot
#
# Scatter Plot
#
# Bar Plot
#
# Histogram
#
# Pie Chart

# %% [markdown]
# Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data
# plot a scatter plot.

# %% [markdown]
# A scatter plot is a type of data visualization used to display the relationship between two numerical variables. It is especially useful when you want to understand how two variables are related to each other or if there is any pattern or correlation between them.

# %%
import numpy as np
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))

# %%
import matplotlib.pyplot as plt

plt.scatter(x,y)
plt.xlabel('X Label')
plt.ylabel('Y Label')
plt.title('This is x versus Y')
# Out:
# Text(0.5, 1.0, 'This is x versus Y')

# %% [markdown]
# Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.
# Use the following data:
# import numpy as np
# For line 1: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([0, 100, 200, 300, 400, 500])
# For line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])
# For line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])
# For line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])

# %% [markdown]
# The subplot() function in Matplotlib is used to create multiple plots or subplots within a single figure

# %%
x1 = np.array([0, 1, 2, 3, 4, 5])
y1 = np.array([0, 100, 200, 300, 400, 500])
x2 = np.array([0, 1, 2, 3, 4, 5])
y2 = np.array([50, 20, 40, 20, 60, 70])
x3 = np.array([0, 1, 2, 3, 4, 5])
y3 = np.array([10, 20, 30, 40, 50, 60])
x4 = np.array([0, 1, 2, 3, 4, 5])
y4 = np.array([200, 350, 250, 550, 450, 150])

plt.subplot(2,2,1)
plt.plot(x1,y1)
plt.title('Subplot 1')

plt.subplot(2,2,2)
plt.plot(x2,y2)
plt.title('Subplot 2')

plt.subplot(2,2,3)
plt.plot(x3,y3)
plt.title('Subplot 3')

plt.subplot(2,2,4)
plt.plot(x4,y4)
plt.title('Subplot 4')

plt.tight_layout()
plt.show()

# %% [markdown]
# Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.

# %% [markdown]
# A bar plot is a type of data visualization used to display and compare categorical data. It represents data as rectangular bars, where the length of each bar corresponds to the value of the data it represents.
#
# Bar plots are particularly useful for the following purposes:
#
# Comparison
#
# Categorical Data Representation
#
# Data Distribution
#
# Comparison of Trends
#
# Data Exploration

# %%
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

# %%
plt.bar(company,profit)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.barh(company,profit)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# Q5: What is a box plot? Why is it used? Using the following data plot a box plot.
# box1 = np.random.normal(100, 10, 200)
# box2 = np.random.normal(90, 20, 200)

# %% [markdown]
# A box plot, also known as a box-and-whisker plot, is a graphical representation of the distribution of numerical data through quartiles.

# %% [markdown]
# Box plots are particularly useful for the following purposes:
#
# Comparison of Distributions
#
# Identification of Outliers
#
# Data Symmetry and Skewness
#
# Data Spread and Variability
#
# Data Range and Potential Outliers

# %%
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)

# %%
plt.boxplot([box1,box2])
plt.xticks(range(1, 3), ['Data 1', 'Data 2'])
plt.show()
