# %% [markdown]
# Q1. Explain why we have to use the Exception class while creating a Custom Exception.
# Note: Here Exception class refers to the base class for all the exceptions.

# %% [markdown]
# When creating custom exceptions in Python, it is advisable to derive them from the Exception class or one of its subclasses. By doing so, we inherit the existing functionality and behavior of built-in exceptions, ensuring consistent exception handling throughout our codebase. Inheriting from Exception also makes our code more self-explanatory and communicates the intent clearly to other developers. Additionally, it allows us to leverage the exception hierarchy in Python, enabling structured and granular exception handling. Overall, using the Exception class as the base class for custom exceptions provides consistency, functionality, and promotes code readability and maintainability.

# %% [markdown]
# Q2. Write a python program to print Python Exception Hierarchy.

# %%
def print_exception_hierarchy(exception_class, indent=0):
    print(' ' * indent + exception_class.__name__)
    for subclass in exception_class.__subclasses__():
        print_exception_hierarchy(subclass, indent + 4)

print_exception_hierarchy(Exception)
# Out:
# Exception
#     TypeError
#         FloatOperation
#         MultipartConversionError
#     StopAsyncIteration
#     StopIteration
#     ImportError
#         ModuleNotFoundError
#         ZipImportError
#     OSError
#         ConnectionError
#             BrokenPipeError
#             ConnectionAbortedError
#             ConnectionRefusedError
#             ConnectionResetError
#                 RemoteDisconnected
#         BlockingIOError
#         ChildProcessError
#         FileExistsError
#         FileNotFoundError
#         IsADirectoryError
#         NotADirectoryError
#         InterruptedError
#             InterruptedSystemCall
#         PermissionError
#         ProcessLookupError
#         TimeoutError
#         UnsupportedOperation
#         itimer_error
#         herror
#         gaierror
#         SSLError
#             SSLCertVerificationError
#             SSLZeroReturnError
#             SSLWantWriteError
#             SSLWantReadError
# ...

# %% [markdown]
# Q3. What errors are defined in the ArithmeticError class? Explain any two with an example.

# %% [markdown]
# The ArithmeticError class in Python is the base class for exceptions that occur during arithmetic operations. It is a subclass of the Exception class and provides a common interface for specific arithmetic-related exceptions. Here are two examples of exceptions derived from the ArithmeticError class:
# ZeroDivisionError: This exception is raised when attempting to divide a number by zero.
# OverflowError: This exception is raised when the result of an arithmetic operation exceeds the maximum representable value.

# %%
try:
    result = 10 / 0
except ZeroDivisionError:
    print("Cannot divide by zero.")

# Output: Cannot divide by zero.
# Out:
# Cannot divide by zero.

# %%
import sys

try:
    result = sys.maxsize + 1
except OverflowError:
    print("Arithmetic operation overflow.")

# Output: Arithmetic operation overflow.

# %% [markdown]
# Q4. Why LookupError class is used? Explain with an example KeyError and IndexError.

# %% [markdown]
# The LookupError class in Python is the base class for exceptions that occur when a key or index lookup fails.

# %%
my_dict = {'a': 1, 'b': 2, 'c': 3}

try:
    value = my_dict['d']
except LookupError as e:
    print(e)
# Output: Key not found in the dictionary.
# Out:
# 'd'

# %%
my_list = [1, 2, 3]

try:
    value = my_list[3]
except LookupError as e:
    print(e)

# Output: Index out of range.
# Out:
# list index out of range

# %% [markdown]
# Q5. Explain ImportError. What is ModuleNotFoundError?

# %% [markdown]
# Ans) ImportError: This exception is raised when an imported module or package cannot be found or loaded.
# ModuleNotFoundError: This exception is a subclass of ImportError and is specifically raised when a module or package is not found.

# %% [markdown]
# Q6. List down some best practices for exception handling in python.

# %% [markdown]
# Ans) Best Practices for Exception Handling in python:
#
# 1.Always Use Specific Exception rather than directly writing "Exception"
# 2.Print always a Valid Message
# 3.Always write a log
# 4.Always try to avoid to write multiple exception handling
# 5.Prepare a proper Documentation
